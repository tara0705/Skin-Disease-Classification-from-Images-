# %%
import os
import pandas as pd

IMAGE_DIR = "data/raw/HAM10000_images"
CSV_PATH = "data/raw/HAM10000_metadata.csv"

print("Images:", len(os.listdir(IMAGE_DIR)))

df = pd.read_csv(CSV_PATH)
print("CSV rows:", len(df))
